# %% [markdown]
# <a href="https://colab.research.google.com/github/410351398/fin_data/blob/main/%E8%AE%80%E5%8F%96csv%E6%AA%94%E8%B3%87%E6%96%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/410351398/fin_data/main/TEJ.csv"

# %%
df = pd.read_csv(url, index_col=0)

# %%
df
# Out:
#               年/月   季別  合併(Y/N)            月份   幣別           存貨  \
# 公司
# 2330 台積電  2023/12    4        Y            12  NTD  250,997,088
# 2330 台積電  2023/09    3        Y            09  NTD  262,090,072
# 2330 台積電  2023/06    2        Y            06  NTD  234,332,949
# 2330 台積電  2023/03    1        Y            03  NTD  216,067,981
# NaN           NaN  NaN      NaN           NaN  NaN          NaN
# 公司            年/月   季別  合併(Y/N)  單季(Q)/單半年(H)   月份           幣別
# 2330 台積電  2023/12    4        Y             Q   12          NTD
# 2330 台積電  2023/09    3        Y             Q   09          NTD
# 2330 台積電  2023/06    2        Y             Q   06          NTD
# 2330 台積電  2023/03    1        Y             Q   03          NTD
# NaN           NaN  NaN      NaN           NaN  NaN          NaN
# 公司            年/月   季別  合併(Y/N)            月份   幣別           存貨
# 1101 台泥   2023/12    4        Y            12  NTD   11,494,015
# 1101 台泥   2023/09    3        Y            09  NTD   13,443,179
# ...
